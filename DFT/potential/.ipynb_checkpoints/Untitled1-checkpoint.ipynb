# %%
from ase.io.cube import read_cube_data
import pandas as pd
import numpy as np
from ase import Atoms
from ase.visualize import view
import math
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_table('dftzetaA.txt')

# %%
df.head()
# Out:
#          rx        ry        rz          vx   vy             vz   time   \
# 0 -1.830549 -4.190756  3.001410   521.189026 -0.0  122563.210938   8.83
# 1  2.565126 -0.099269  3.000968 -3081.871338 -0.0  115552.304688   4.83
# 2  4.151197  0.225316  3.002993  2068.566162 -0.0   93673.312500  17.08
# 3  4.119476  6.204773  3.006126 -3760.801514 -0.0  115588.554688  12.38
# 4  2.026567 -4.088255  3.004584   202.877274 -0.0  115262.023438   5.68
#
#     mass    ax   ay   bx   by   cx          cy  rw    rn  flags      ui
# 0  22.99  35.0  0.0 -0.0 -0.0  0.0  125.243645   1   902    128  375893
# 1  22.99  35.0  0.0 -0.0  0.0  0.0  123.472237   1  1381    128  376372
# 2  22.99  35.0  0.0 -0.0  0.0  0.0  126.265045   1  1419    128  376410
# 3  22.99  35.0  0.0 -0.0 -0.0  0.0  123.136475   1  2119    128  377110
# 4  22.99  35.0  0.0 -0.0 -0.0  0.0  125.100845   1  2914    128  377905

# %%
X = list(df['rx'])

# %%
Y = list(df['ry'])

# %%
plt.scatter(X,Y,marker='.')

# %%
atom = pd.read_table('zetaA.txt',delim_whitespace=True,names = ('x','y','z','Z','m','f'))

# %%
topIn = atom.query('z > -10 and Z ==49')
topAs = atom.query('z > -10 and Z ==33')

# %%
In_X = list(topIn['x'])
In_Y = list(topIn['y'])

# %%
As_X = list(topAs['x'])
As_Y = list(topAs['y'])

# %%
plt.figure(figsize=(5,10))
plt.scatter(X,Y,marker='.')
plt.scatter(In_X,In_Y,marker='*',s=100)
plt.scatter(As_X,As_Y,marker='o',s=150)

# %%
atom['count']=0

# %%
atom.head(20)
# Out:
#           x        y        z   Z          m  f  count
# 0  -4.26590 -2.27750  0.00000  33   74.92159  0      0
# 1  -4.25654  2.24968 -0.01013  33   74.92159  0      0
# 2  -0.01422 -2.27430 -0.00589  33   74.92159  0      0
# 3  -0.01541  2.24689 -0.01370  33   74.92159  0      0
# 4  -4.27514 -8.55219  0.40268  49  114.81800  0      0
# 5  -0.00585 -8.55219  0.40268  49  114.81800  0      0
# 6  -2.13867 -3.91204 -0.51458  49  114.81800  0      0
# 7  -2.13222 -0.00643 -1.03772  49  114.81800  0      0
# 8  -2.13517  3.88474 -0.54204  49  114.81800  0      0
# 9   2.12989 -4.00769 -0.18183  49  114.81800  0      0
# 10  2.13760  0.00000  0.40268  49  114.81800  0      0
# 11  2.13386  3.97622 -0.19068  49  114.81800  0      0
# 12 -2.13831 -6.50924 -0.77421  33   74.92159  0      0
# 13 -2.13707  6.48101 -0.78036  33   74.92159  0      0
# 14  2.13292 -6.57118 -0.71185  33   74.92159  0      0
# 15  2.13463  6.54150 -0.70977  33   74.92159  0      0
# ...

# %%
data,atoms=read_cube_data('zeta_A_potential.cube')


atomxyz = atoms.get_positions()
symbols = atoms.get_chemical_symbols()

atomdf = pd.concat([pd.DataFrame(atomxyz,columns=['x', 'y', 'z']),
                    pd.DataFrame(symbols,columns=['atom'])],
                   axis=1)
atomdf.head(20)
# Out:
#            x          y          z atom
# 0   0.394566   7.268466  17.891313   As
# 1   0.397110  11.945721  17.888549   As
# 2   4.634772   7.269475  17.892170   As
# 3   4.635030  11.945723  17.889206   As
# 4   0.384195   1.076472  18.505110   In
# 5   4.626414   1.077207  18.506570   In
# 6   2.516343   5.665506  17.472971   In
# 7   2.519498   9.620952  16.598021   In
# 8   2.517322  13.552077  17.473483   In
# 9   6.784810   5.615318  17.718589   In
# 10  6.791886   9.615280  18.211208   In
# 11  6.786424  13.600340  17.717593   In
# 12  2.513617   3.043474  17.018590   As
# 13  2.515290  16.174927  17.019931   As
# 14  6.783909   3.034384  17.066563   As
# 15  6.785072  16.183645  17.071977   As
# 16  0.359419   3.187948  15.334290   In
# 17  5.282489   7.420127  15.225939   In
# 18  5.286891  11.803791  15.220814   In
# 19  0.360246  16.033521  15.338158   In
